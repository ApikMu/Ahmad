# %% [markdown]
# LATIHAN SOAL
#
# Diberikan data mahasiswa tentukan/visualisasikan (Gunakan dataset H05.csv dari pertemuan sebelumnya):
#
# 1. Histogram distribusi nilai matematika.
# 2. Diagram batang horizontal banyaknya mahasiswa masing-masing fakultas.
# 3. Diagram pie banyaknya mahasiswa masing-masing fakultas
# 4. Berdasarkan diagram pie dan batang horizontal manakah fakultas dengan mahasiswa terbanyak? manakan diagram yang lebih baik dalam menampilkan fakultas dengan mahasiswa terbanyak dan mengapa?
# 5. Scatter plot dengan nilai kimia sebagai x dan fisika sebagai y.

# %%
# !pip upgrade
# Out:
#   Cell In[25], line 1
#     -m pip upgrade
#        ^
# SyntaxError: invalid syntax

# %%
# !pip install matplotlib.pylpot
# Out:
# ERROR: Could not find a version that satisfies the requirement matplotlib.pylpot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pylpot

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
data = pd.read_csv('C:/Users/HP/Downloads/H05.csv')
data
# Out:
#                           nama fakultas  nilai_mat  nilai_kim  nilai_fis
# 0         Farhan Fathur Rahman    FMIPA      57.21      34.14      38.93
# 1               Steven Margono    FMIPA      67.43      51.50      57.20
# 2                 Ryan Sentosa    SAPPK      90.62      37.38      40.73
# 3         Muhajah Babny Muslim    FMIPA      72.31      38.80      44.79
# 4             Alvin Natawiguna     FTSL      65.45      57.67      56.39
# ...                        ...      ...        ...        ...        ...
# 5130               Khoirrashif    SITHR      66.14      46.82      56.74
# 5131      Jefri Hendri Adriano     FTSL      53.68      34.74      33.76
# 5132               Iki Hidayat     FITB      69.63      35.04      37.65
# 5133  Muhammad Nashir Sitompul      FTI      79.69      39.06      50.17
# 5134     Billy Richardo Sagala     STEI      68.68      51.23      66.18
#
# [5135 rows x 5 columns]

# %%
#1.Histogram distribusi nilai matematika
plt.figure(figsize=(8, 6))
plt.hist(data["nilai_mat"], bins=10, color="skyblue", edgecolor="black")
plt.title("Histogram Distribusi Nilai Matematika")
plt.xlabel("Nilai Matematika")
plt.ylabel("Frekuensi")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
#2. Diagram batang horizontal banyaknya mahasiswa masing-masing fakultas
faculty_counts = data["fakultas"].value_counts()
plt.figure(figsize=(8, 6))
faculty_counts.plot(kind="barh", color="skyblue", edgecolor="black")
plt.title("Diagram Batang Horizontal Mahasiswa per Fakultas")
plt.xlabel("Jumlah Mahasiswa")
plt.ylabel("Fakultas")
plt.grid(axis="x", linestyle="--", alpha=0.7)
plt.show()

# %%
#3. Diagram pie banyaknya mahasiswa masing-masing fakultas
plt.figure(figsize=(8, 8))
faculty_counts.plot(kind="pie", autopct="%1.1f%%", startangle=140, colors=["#ff9999", "#66b3ff", "#99ff99", "#ffcc99"])
plt.title("Diagram Pie Mahasiswa per Fakultas")
plt.ylabel("")  # Menghilangkan label default
plt.show()

# %%
4.#Analisis diagram batang vs diagram pie
print("""
Analisis:
Diagram batang horizontal lebih baik dalam menampilkan fakultas dengan mahasiswa terbanyak. 
Hal ini karena diagram batang memberikan informasi kuantitatif secara lebih jelas dan 
memungkinkan perbandingan visual yang lebih mudah antar kategori dibandingkan dengan diagram pie.
""")
# Out:
# Analisis:
# Diagram batang horizontal lebih baik dalam menampilkan fakultas dengan mahasiswa terbanyak.
# Hal ini karena diagram batang memberikan informasi kuantitatif secara lebih jelas dan
# memungkinkan perbandingan visual yang lebih mudah antar kategori dibandingkan dengan diagram pie.

# %%
# 5. Scatter plot nilai Kimia (x) dan Fisika (y)
plt.figure(figsize=(8, 6))
plt.scatter(data["nilai_kim"], data["nilai_fis"], color="pink", alpha=0.7)
plt.title("Scatter Plot Nilai Kimia vs Fisika")
plt.xlabel("Nilai Kimia")
plt.ylabel("Nilai Fisika")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()
